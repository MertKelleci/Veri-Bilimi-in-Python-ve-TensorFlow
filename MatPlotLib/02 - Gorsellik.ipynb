# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
numpyList = np.linspace(0,10,20)

# %%
numpyList1 = numpyList ** 2

# %%
(myFigure, myAxis) = plt.subplots()
myAxis.plot(numpyList, numpyList1, "g")
myAxis.plot(numpyList1, numpyList, "b")
#color="rgb code"
#alpha=0-1 transparanlık
#linewidth=kalınlık
#linestyle=stil ("--",":", "-.")
#marker=veri noktalarını işaretle ("+")
#markersize, markerfacecolor

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(numpyList, numpyList1)

# %% [markdown]
# ## Histogram

# %%
plt.hist(np.random.randint(0,100,50))
# Out:
# (array([7., 8., 6., 6., 6., 1., 3., 6., 2., 5.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(np.random.randint(0,100,50))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2acb7c017d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2acb7c03010>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2acb7c00b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2acb7c10450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2acb7c10e90>],
#  'means': []}
